# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import random
import peakutils
import IPython.display

# from listen.data.librispeech import librispeech
from listen.data.an4 import an4
from pyAudioAnalysis import audioBasicIO
from pyAudioAnalysis import audioSegmentation as aS

an4data = an4.AN4(conversion=False, debug=False)

# spg = Spectrogram(fft_size=2048, step_size=128, thresh=400)
train = list(an4data.trainset)
ch = random.choice(range(len(train)))
# ch = 179
samples, t = train[ch]
rate, data = audioBasicIO.readAudioFile(samples)
# [flagsInd, classesAll, acc, CM] = aS.mtFileClassification(samples, "listen/data/pyAudioAnalysis/data/svmSM", "svm", True)
segments = aS.silenceRemoval(data, rate, 0.02, 0.001, smoothWindow=0.0, plot = True)
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(24, 10))
ax[0].plot(data)
print(t)
print(segments)
# Out:
# ['RUBOUT', 'I', 'R', 'D', 'D', 'J', 'ONE']
# [[0.51700000000000002, 0.73999999999999999], [1.296, 1.544], [1.55, 1.923]]
